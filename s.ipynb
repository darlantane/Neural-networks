# %%
from transformers import pipeline

# Chargement du modèle
classifier = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english"
)

def analyze_sentiments(texts):
    results = classifier(texts)
    return results
# Out:
# Device set to use cpu

# %%
from dat import comments

if __name__ == "__main__":

    print("Analyse des sentiments :\n")

    results = analyze_sentiments(comments)

    for comment, result in zip(comments, results):
        print(f"Texte : {comment}")
        print(f"Sentiment : {result['label']} (score: {result['score']:.2f})\n")
# Out:
# Analyse des sentiments :
#
# Texte : I love this product, it's amazing!
# Sentiment : POSITIVE (score: 1.00)
#
# Texte : This is the worst experience I've ever had.
# Sentiment : NEGATIVE (score: 1.00)
#
# Texte : Not bad, but could be better.
# Sentiment : NEGATIVE (score: 0.80)
#
# Texte : Absolutely fantastic service!
# Sentiment : POSITIVE (score: 1.00)
#
# Texte : I would not recommend this to anyone.
# Sentiment : NEGATIVE (score: 0.96)
